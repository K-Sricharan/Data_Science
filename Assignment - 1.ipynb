# %%
1. In the below elements which of them are values or an expression? eg:- values can be
integer or string and expressions will be mathematical operators.

* = Mathematical operator

hello = string

-87.8 = float

- = expression

/ = mathematical operator

+ = mathematical operator

6 = integer

2. What is the difference between string and variable?

Ans: string is a group of words. In below example ineuron is string.
    ex: "ineoron"
        
    Variable is a name given to Store data.
    ex: a = 10
        
3. Describe three different data types.

Ans: int: int is used to store integer type of data
        ex: 10, 100,1000 etc...
    float: It is used to store decimal type of values.
        ex: 999.999 etc...
    bool: it is used to true boolean value.
        ex: True, False
            
4. What is an expression made up of? What do all expressions do?

Ans:It is a combination of operands and operators. It is used to evaluate values.
    
    
5. This assignment statements, like spam = 10. What is the difference between an
expression and a statement?

Ans:expression is a type of value which produces some result Whereas statement is a line of statemet which may give result or 
    may not return result.
    
    
6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1

Ans: bacon = 23

7. What should the values of the following two terms be?
'spam' + 'spamspam'
'spam' * 3

Ans: 'spam' + 'spamspam' = 'spamspamspam'
     'spam' * 3 = 'spamspamspam'
        
8. Why is eggs a valid variable name while 100 is invalid?

Ans: eggs is group of letters which is consider as variable name whereas while keyword itself a condition statement so, we can't 
    use while statement as varialble name.

9. What three functions can be used to get the integer, floating-point number, or string
version of a value?

Ans:Integer = int
    floating-point number = float
    string = str
    
    
10. Why does this expression cause an error? How can you fix it?
'I have eaten' + 99 +  'burritos.'

Ans: we can only concatinate string. we can not concatinate integer with string.
     In order to correct this we can use this as below
        
     'I have eaten' + ' 99 ' +  'burritos.' 
    
     output: 'I have eaten 99 burritos.'
